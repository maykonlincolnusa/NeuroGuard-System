# %% [markdown]
# # Análise Exploratória de Dados (EDA)
#
# Este notebook realiza análise exploratória de dados neurológicos (EEG/EDF).

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

from src.data_engineering.edf_reader import EDFReader
from src.analytics.exploratory import ExploratoryAnalyzer

# %%
# Carregar dados EDF
edf_path = Path("../data/raw/sample.edf")

reader = EDFReader(verbose=True)
raw_data = reader.load_edf(edf_path)

# Informações básicas
info = reader.get_info()
print("Informações do arquivo:")
for key, value in info.items():
    print(f"  {key}: {value}")
